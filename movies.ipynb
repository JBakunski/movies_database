# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
genres = pd.read_csv("C:\\Users\\jacek\\Downloads\\tmdb_genres.csv")
movies = pd.read_csv("C:\\Users\\jacek\\Downloads\\tmdb_movies.csv")

# %%
genres.head()
# Out:
#    Unnamed: 0           genres
# 0       28.00           Action
# 1       12.00        Adventure
# 2       14.00          Fantasy
# 3       16.00        Animation
# 4      878.00  Science Fiction

# %%
movies.head()
# Out:
#    Unnamed: 0     budget                                      homepage  \
# 0           0  237000000                   http://www.avatarmovie.com/
# 1           1  300000000  http://disney.go.com/disneypictures/pirates/
# 2           2  245000000   http://www.sonypictures.com/movies/spectre/
# 3           3  250000000            http://www.thedarkknightrises.com/
# 4           4  260000000          http://movies.disney.com/john-carter
#
#        id original_language                            original_title  \
# 0   19995                en                                    Avatar
# 1     285                en  Pirates of the Caribbean: At World's End
# 2  206647                en                                   Spectre
# 3   49026                en                     The Dark Knight Rises
# 4   49529                en                               John Carter
#
#                                             overview  popularity release_date  \
# 0  In the 22nd century, a paraplegic Marine is di...      150.44   2009-12-10
# 1  Captain Barbossa, long believed to be dead, ha...      139.08   2007-05-19
# 2  A cryptic message from Bond’s past sends him o...      107.38   2015-10-26
# 3  Following the death of District Attorney Harve...      112.31   2012-07-16
# 4  John Carter is a war-weary, former military ca...       43.93   2012-03-07
#
#       revenue  runtime    status  \
# 0  2787965087   162.00  Released
# 1   961000000   169.00  Released
# 2   880674609   148.00  Released
# 3  1084939099   165.00  Released
# 4   284139100   132.00  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar          7.20       11800
# 1  Pirates of the Caribbean: At World's End          6.90        4500
# 2                                   Spectre          6.30        4466
# 3                     The Dark Knight Rises          7.60        9106
# 4                               John Carter          6.10        2124
#
#    genre_id
# 0     28.00
# 1     12.00
# 2     28.00
# 3     28.00
# 4     28.00

# %% [markdown]
# ### 10 najlepszych filmów pod względem średniej oceny przy ilości głosów powyżej 3 kwartyla

# %%
movies.sort_values(by='vote_average', ascending=False, inplace=True)
movies.head()
movies[movies['vote_count'] > movies['vote_count'].quantile(0.75)].head(10)
# Out:
#       Unnamed: 0     budget  \
# 1881        1881   25000000
# 3337        3337    6000000
# 2294        2294   15000000
# 3865        3865    3300000
# 2731        2731   13000000
# 3232        3232    8000000
# 662          662   63000000
# 1818        1818   22000000
# 1990        1990   18000000
# 65            65  185000000
#
#                                                homepage      id  \
# 1881                                                NaN     278
# 3337                       http://www.thegodfather.com/     238
# 2294             http://movies.disney.com/spirited-away     129
# 3865                  http://sonyclassics.com/whiplash/  244786
# 2731                                                NaN     240
# 3232                                                NaN     680
# 662          http://www.foxmovies.com/movies/fight-club     550
# 1818                     http://www.schindlerslist.com/     424
# 1990  http://www.starwars.com/films/star-wars-episod...    1891
# 65         http://thedarkknight.warnerbros.com/dvdsite/     155
#
#      original_language            original_title  \
# 1881                en  The Shawshank Redemption
# 3337                en             The Godfather
# 2294                ja                  千と千尋の神隠し
# 3865                en                  Whiplash
# 2731                en    The Godfather: Part II
# 3232                en              Pulp Fiction
# 662                 en                Fight Club
# 1818                en          Schindler's List
# 1990                en   The Empire Strikes Back
# 65                  en           The Dark Knight
#
#                                                overview  popularity  \
# 1881  Framed in the 1940s for the double murder of h...      136.75
# 3337  Spanning the years 1945 to 1955, a chronicle o...      143.66
# 2294  A ten year old girl who wanders away from her ...      118.97
# 3865  Under the direction of a ruthless instructor, ...      192.53
# 2731  In the continuing saga of the Corleone crime f...      105.79
# 3232  A burger-loving hit man, his philosophical par...      121.46
# 662   A ticking-time-bomb insomniac and a slippery s...      146.76
# 1818  The true story of how businessman Oskar Schind...      104.47
# 1990  The epic saga continues as Luke Skywalker, in ...       78.52
# 65    Batman raises the stakes in his war on crime. ...      187.32
#
#      release_date     revenue  runtime    status  \
# 1881   1994-09-23    28341469   142.00  Released
# 3337   1972-03-14   245066411   175.00  Released
# 2294   2001-07-20   274925095   125.00  Released
# 3865   2014-10-10    13092000   105.00  Released
# 2731   1974-12-20    47542841   200.00  Released
# 3232   1994-10-08   213928762   154.00  Released
# 662    1999-10-15   100853753   139.00  Released
# 1818   1993-11-29   321365567   195.00  Released
# 1990   1980-05-17   538400000   124.00  Released
# 65     2008-07-16  1004558444   152.00  Released
#
#                                                 tagline  \
# 1881  Fear can hold you prisoner. Hope can set you f...
# 3337                         An offer you can't refuse.
# 2294     The tunnel led Chihiro to a mysterious town...
# 3865    The road to greatness can take you to the edge.
# 2731  I don't feel I have to wipe everybody out, Tom...
# 3232  Just because you are a character doesn't mean ...
# 662                             Mischief. Mayhem. Soap.
# 1818    Whoever saves one life, saves the world entire.
# 1990                         The Adventure Continues...
# 65                                      Why So Serious?
#
#                          title  vote_average  vote_count  genre_id
# 1881  The Shawshank Redemption          8.50        8205     18.00
# 3337             The Godfather          8.40        5893     18.00
# 2294             Spirited Away          8.30        3840     14.00
# 3865                  Whiplash          8.30        4254     18.00
# 2731    The Godfather: Part II          8.30        3338     18.00
# 3232              Pulp Fiction          8.30        8428     53.00
# 662                 Fight Club          8.30        9413     18.00
# 1818          Schindler's List          8.30        4329     18.00
# 1990   The Empire Strikes Back          8.20        5879     12.00
# 65             The Dark Knight          8.20       12002     18.00

# %%
movies['release_date'] = pd.to_datetime(movies['release_date'])
movies.dropna(subset=['release_date'], inplace=True)

# %%
movies['release_year'] = movies['release_date'].dt.year
movies.set_index('release_year', inplace=True)
pd.set_option('display.float_format', '{:,.2f}'.format)
movies.head(2)
movies_2 = movies.pivot_table(index='release_year', values=['revenue', 'budget'], aggfunc='mean')
movies_selected = movies_2.loc[2010:2016]
movies_selected
# Out:
#                     budget        revenue
# release_year
# 2010         34,495,410.94  90,438,110.08
# 2011         34,772,320.34  92,004,130.76
# 2012         34,922,031.99 116,065,914.64
# 2013         35,523,293.65 101,348,455.82
# 2014         30,959,887.86 101,346,599.11
# 2015         31,132,163.74 105,439,926.95
# 2016         45,703,269.23 139,049,586.04

# %% [markdown]
# ### Graficzna reprezentacja porównania średniego budżetu i średniego przychodu filmu w latach 2010-2016

# %%
def million(x, pos):
        return '{:2.1f}M'.format(x*1e-6)
fig = plt.figure()
formatter = plt.FuncFormatter(million)
axes = fig.add_axes([0,0,1,1])
axes.set_title('Średni przychód i budżet filmu w latach 2010 - 2016')
axes.yaxis.set_major_formatter(formatter)
axes.plot(movies_selected['budget'], color='red', linewidth=3, label='budżet')
axes.bar(movies_selected.index , movies_selected['revenue'], label='przychód')
axes.legend(loc=(1.05,0.8))

# %% [markdown]
# ### Ilość filmów z każdego gatunku w bazie

# %%
movies_with_genres = movies.merge(genres, how='inner', left_on='genre_id', right_on='Unnamed: 0')
movies_with_genres['genres'].value_counts()
# Out:
# Drama              1207
# Comedy             1042
# Action              754
# Adventure           339
# Horror              300
# Crime               195
# Thriller            194
# Animation           123
# Fantasy             117
# Romance             106
# Science Fiction      96
# Documentary          89
# Family               56
# Mystery              41
# Music                34
# Western              27
# History              25
# War                  24
# TV Movie              4
# Foreign               2
# Name: genres, dtype: int64

# %% [markdown]
# ### Średni czas trwania filmu w  minutach według gatunku

# %%
movies_with_genres_pivot = movies_with_genres.pivot_table(index='genres', values=['runtime'], aggfunc='mean')
movies_with_genres_pivot.sort_values(by='runtime', ascending=False)
# Out:
#                  runtime
# genres
# History           133.96
# War               126.12
# Western           117.93
# Drama             115.52
# Adventure         113.06
# Crime             112.14
# TV Movie          110.50
# Action            109.06
# Science Fiction   109.03
# Romance           107.09
# Fantasy           106.49
# Thriller          105.69
# Music             102.85
# Mystery           100.61
# Comedy            100.46
# Horror             94.75
# Documentary        93.51
# Family             89.80
# Animation          89.55
# Foreign            83.00

# %% [markdown]
# ### Histogram czasu trwania filmów historycznych

# %%
history_movies = movies_with_genres.loc[movies_with_genres['genres'] == 'History']
history_movies['runtime'].plot(kind='hist', bins=30, grid=True, yticks=[5, 10, 15])
# Out:
# <AxesSubplot:ylabel='Frequency'>
